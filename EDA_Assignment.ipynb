# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
import pandas as pd
df=pd.read_csv('winequality-red.csv')
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Ans:- The correlation values lies between -1 to 1
# The key features are Fixed acidity. ...
#
# Volatile acidity:-
#
# Citric acid. ...
#
# Residual sugar. ...
#
# Chlorides. ...
#
# Free sulfur dioxide. ...
#
# Total sulfur dioxide. ...
#
# Density.
#
# PH
#
# sulphates
#
# alcohol
#
# quality

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %% [markdown]
# Ans:- we can handle missing data in wine quality dataset by many ways Missing values can be handled by deleting the rows or columns having null values. If columns have more than half of the rows as null then the entire column can be dropped. The rows which are having one or more columns values as null can also be dropped.
# 1) MEAN IMPUTATION :- It will fill all the missing box with mean of that particular datasets attribute
# 2) MEDIAN IMPUTATION:-It will fill all the missing box with median of that particular datasets attribute
# 3) MODE IMPUTATION :- It will fill all the missing box with median of that particular datasets attribute

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
import pandas as pd
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
import numpy as np
df['gender']=np.where(df['gender']=='female',0,1)

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0       0        group B           bachelor's degree  standard
# 1       0        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
df['test preparation course']=np.where(df['test preparation course']=='none',0,1)

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       0        group B           bachelor's degree      standard
# 1       0        group C                some college      standard
# 2       0        group B             master's degree      standard
# 3       1        group A          associate's degree  free/reduced
# 4       1        group C                some college      standard
# 5       0        group B          associate's degree      standard
# 6       0        group B                some college      standard
# 7       1        group B                some college  free/reduced
# 8       1        group D                 high school  free/reduced
# 9       0        group B                 high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                        0          72             72             74
# 1                        1          69             90             88
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encod=LabelEncoder()
encoded=encod.fit_transform(df['race/ethnicity'])

# %%
df['race/ethnicity']=encoded

# %%
df.head(5)
# Out:
#    gender  race/ethnicity parental level of education         lunch  \
# 0       0               1           bachelor's degree      standard
# 1       0               2                some college      standard
# 2       0               1             master's degree      standard
# 3       1               0          associate's degree  free/reduced
# 4       1               2                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 0                        0          72             72             74
# 1                        1          69             90             88
# 2                        0          90             95             93
# 3                        0          47             57             44
# 4                        0          76             78             75

# %%
encoded_parental_lavel=encod.fit_transform(df['parental level of education'])
df['parental level of education']=encoded_parental_lavel

# %%
df['lunch']=np.where(df['lunch']=='standard	',1,0)

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               1                            1      0
# 1         0               2                            4      0
# 2         0               1                            3      0
# 3         1               0                            0      0
# 4         1               2                            4      0
# ..      ...             ...                          ...    ...
# 995       0               4                            3      0
# 996       1               2                            2      0
# 997       0               2                            2      0
# 998       0               3                            4      0
# 999       0               3                            4      0
#
#      test preparation course  math score  reading score  writing score
# 0                          0          72             72             74
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# there is no any null value present in the dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
percentage=df.gender.value_counts(normalize=True)*100
dt=['male','female']
plt.figure(figsize=(15,7))
plt.pie(percentage,labels=dt,autopct='%1.1f%%')
plt.show()

# %%
df[['math score', 'reading score','writing score']].value_counts()
# Out:
# math score  reading score  writing score
# 100         100            100              3
# 65          77             74               3
# 73          68             66               2
# 82          93             93               2
#             82             80               2
#                                            ..
# 60          70             70               1
#                            74               1
#             72             68               1
#                            74               1
# 66          74             69               1
# Name: count, Length: 978, dtype: int64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
df=pd.read_csv('StudentsPerformance.csv')
df.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %% [markdown]
# ANS:- I can transform the variables of my data set by transforming gender columns in 0/1 format
#
# test_prepration columns by 0/1
#
# race/etinity as level encoding
#
# parental level of education columns as OneHotEncoding

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
df=pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import numpy as np
log_fixedAcidity= np.log1p(df["fixed acidity"])

# %%
log_density= np.log1p(df["density"])

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
from sklearn import datasets  # to retrieve the iris Dataset
import pandas as pd  # to load the dataframe
from sklearn.preprocessing import StandardScaler  # to standardize the features
from sklearn.decomposition import PCA  
import seaborn as sns

# %%
df=pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
scalar=StandardScaler()
scaled_data=pd.DataFrame(scalar.fit_transform(df))

# %% [markdown]
# Check the Co-relation between features without PCA

# %%
sns.heatmap(scaled_data.corr())
# Out:
# <Axes: >

# %% [markdown]
#  Applying Principal Component Analysis

# %%
pca=PCA(n_components=2)
pca.fit(scaled_data)
data_pca=pca.transform(scaled_data)
data_pca = pd.DataFrame(data_pca,columns=['PC1','PC2'])
data_pca.head()
# Out:
#         PC1       PC2
# 0 -1.779442  1.157303
# 1 -1.004185  2.071838
# 2 -0.915783  1.393434
# 3  2.404077 -0.213792
# 4 -1.779442  1.157303

# %%
sns.heatmap(data_pca.corr())
# Out:
# <Axes: >
